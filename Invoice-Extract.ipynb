# %%
from paddleocr import PaddleOCR, draw_ocr
from PIL import Image, ImageDraw, ImageFont
import numpy as np
from shapely.geometry import Polygon
import json
import re

# %%
import os
os.getcwd()

# %%
work_dir = "E:/Works/narendra_tasks/invoice-ocr/docai/pocr"

# %%
ocr_model = PaddleOCR(lang='en', use_gpu=True)

# %% [markdown]
# ### Read Template Configuration file template_config.json

# %%
template_config_file = f"{work_dir}/template_config.json"
with open(template_config_file) as f:
    configdata = json.load(f)

# %% [markdown]
# <div class="alert alert-block alert-danger"> <br>
#     - Read PDF
#     - Convert to Image
#     - Scan all pages/images
# </div>

# %% [markdown]
# #### Read folder  for pdf and convert to images

# %%
import fitz
import shutil

processed_folder = f"{work_dir}/processed_files"
temp_dir = f"{work_dir}/temp_files"

def convert_pdf_to_image(temp_dir):
    dpi = 300
    zoom = dpi/72    
    magnify = fitz.Matrix(zoom, zoom)
    file_array = []
    for filename in os.listdir(temp_dir):
        if filename.lower().endswith(".pdf"):
            pdf_path = os.path.join(temp_dir, filename)
    
            doc = fitz.open(pdf_path)
    
            for page_num, page in enumerate(doc):
                count = page_num + 1
                pix = page.get_pixmap(matrix=magnify)
                output_path = os.path.join(processed_folder, f"{os.path.splitext(filename)[0]}_page_{count}.png")
                pix.save(output_path)
                file_array.append(f"{os.path.splitext(filename)[0]}_page_{count}.png")
            doc.close()
            shutil.move(pdf_path, f"{processed_folder}/{filename}")
    return file_array

# ----------------------------------------------------

files = os.listdir(temp_dir)
image_files = []
if(len(files)>0):
    image_files = convert_pdf_to_image(temp_dir)
    
print(image_files)
# Out:
# ['Adani_Commercial_HT_II_page_1.png', 'Adani_Commercial_HT_II_page_2.png']

# %% [markdown]
# #### Loop all converted images - First Page find Template. Template Found - Process all Images for Invoice Fileds extraction
# <div class="alert alert-block alert-danger"> <br>
#     Execute Safely - OCR Data
# </div>

# %%
page_data = []
for image_file in image_files:
    image_file_path = f"{processed_folder}/{image_file}"
    # For first page screen search template
    print(image_file_path)
    pimg = Image.open(image_file_path)
    
    pimg = np.asarray(pimg)
    img_height, img_width = pimg.shape[:2]
    ocrdata = ocr_model.ocr(pimg)
    image_result = []
    image_result = {"image":image_file,"ocrdata":ocrdata,"image_height":img_height,"image_width":img_width}
    
    page_data.append(image_result)
# Out:
# E:/Works/narendra_tasks/invoice-ocr/docai/pocr/processed_files/Adani_Commercial_HT_II_page_1.png
# [2024/03/18 15:12:44] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/03/18 15:12:48] ppocr DEBUG: dt_boxes num : 156, elapsed : 4.127188682556152
# [2024/03/18 15:13:53] ppocr DEBUG: rec_res num  : 156, elapsed : 65.04003882408142
# E:/Works/narendra_tasks/invoice-ocr/docai/pocr/processed_files/Adani_Commercial_HT_II_page_2.png
# [2024/03/18 15:13:54] ppocr WARNING: Since the angle classifier is not initialized, it will not be used during the forward process
# [2024/03/18 15:13:54] ppocr DEBUG: dt_boxes num : 219, elapsed : 0.8634653091430664
# [2024/03/18 15:15:04] ppocr DEBUG: rec_res num  : 219, elapsed : 69.34561491012573

# %%
import pprint
pprint.pprint(page_data)
# Out:
# [{'image': 'Adani_Commercial_HT_II_page_1.png',
#   'image_height': 3509,
#   'image_width': 2475,
#   'ocrdata': [[[[[940.0, 36.0], [1194.0, 44.0], [1192.0, 96.0], [939.0, 87.0]],
#                 (' BILL OF SUPPLY', 0.9744073748588562)],
#                [[[92.0, 58.0], [284.0, 58.0], [284.0, 135.0], [92.0, 135.0]],
#                 ('adani', 0.9991832971572876)],
#                [[[2199.0, 58.0],
#                  [2416.0, 58.0],
#                  [2416.0, 95.0],
#                  [2199.0, 95.0]],
#                 ('Scan QR code for', 0.9979081153869629)],
#                [[[1657.0, 77.0],
#                  [1819.0, 77.0],
#                  [1819.0, 113.0],
#                  [1657.0, 113.0]],
#                 ('Electric ', 0.9574827551841736)],
#                [[[1805.0, 77.0],
#                  [1967.0, 77.0],
#                  [1967.0, 117.0],
#                  [1805.0, 117.0]],
#                 ('429510', 0.999929666519165)],
#                [[[1668.0, 110.0],
#                  [1783.0, 110.0],
#                  [1783.0, 146.0],
#                  [1668.0, 146.0]],
#                 ('Smiles', 0.9921110272407532)],
#                [[[2196.0, 102.0],
#                  [2380.0, 106.0],
#                  [2379.0, 147.0],
#                  [2195.0, 142.0]],
#                 (' kiosk payment', 0.9855256676673889)],
#                [[[969.0, 121.0],
#                  [1175.0, 121.0],
#                  [1175.0, 157.0],
#                  [969.0, 157.0]],
#                 ('COMMERCIAL', 0.998623251914978)],
#                [[[1801.0, 121.0],
#                  [1978.0, 121.0],
#                  [1978.0, 157.0],
#                  [1801.0, 157.0]],
#                 ('Points Earned', 0.9998444318771362)],
#                [[[103.0, 150.0],
#                  [269.0, 150.0],
#                  [269.0, 190.0],
#                  [103.0, 190.0]],
#                 ('Electricity', 0.9998012781143188)],
#                [[[1337.0, 154.0],
#                  [1455.0, 154.0],
#                  [1455.0, 190.0],
#                  [1337.0, 190.0]],
#                 ('Joi n u at orow.', 0.6680701971054077)],
#                [[[346.0, 164.0],
#                  [527.0, 164.0],
#                  [527.0, 190.0],
#                  [346.0, 190.0]],
#                 ('The power of service', 0.9918525815010071)],
#                [[[1503.0, 157.0],
#                  [1573.0, 157.0],
#                  [1573.0, 183.0],
#                  [1503.0, 183.0]],
#                 ('ngraha.org', 0.9448158144950867)],
#                [[[110.0, 260.0],
#                  [788.0, 260.0],
#                  [788.0, 296.0],
#                  [110.0, 296.0]],
#                 ('KINGSTONE PROPERTY SERVICE LIMITED', 0.9990326166152954)],
#                [[[902.0, 260.0],
#                  [1042.0, 260.0],
#                  [1042.0, 300.0],
#                  [902.0, 300.0]],
#                 (' BILL DATE', 0.9653487205505371)],
#                [[[1344.0, 256.0],
#                  [1547.0, 256.0],
#                  [1547.0, 292.0],
#                  [1344.0, 292.0]],
#                 (' METER STATUS', 0.9562808275222778)],
#                [[[1661.0, 260.0],
#                  [1871.0, 260.0],
#                  [1871.0, 296.0],
#                  [1661.0, 296.0]],
#                 ('CYCLE NUMBER', 0.976839005947113)],
#                [[[2011.0, 260.0],
#                  [2225.0, 260.0],
#                  [2225.0, 296.0],
#                [[[1344.0, 486.0],
#                  [1554.0, 486.0],
#                  [1554.0, 523.0],
#                  [1344.0, 523.0]],
#                 (' BILLING STATUS', 0.9745789170265198)],
#                [[[1661.0, 490.0],
#                  [1978.0, 490.0],
#                  [1978.0, 526.0],
#                  [1661.0, 526.0]],
#                 (' PRESENT READING DATE', 0.9754866361618042)],
#                [[[2015.0, 493.0],
#                  [2331.0, 493.0],
#                  [2331.0, 519.0],
#                  [2015.0, 519.0]],
#                 ('PREVIOUS READING DATE', 0.9783110022544861)],
#                [[[103.0, 504.0],
#                  [180.0, 504.0],
#                  [180.0, 545.0],
#                  [103.0, 545.0]],
#                 ('PAN', 0.9986477494239807)],
#                [[[273.0, 504.0],
#                  [442.0, 504.0],
#                  [442.0, 541.0],
#                  [273.0, 541.0]],
#                 ('AA*****16P', 0.9650843739509583)],
#                [[[902.0, 523.0],
#                  [1271.0, 523.0],
#                  [1271.0, 559.0],
#                  [902.0, 559.0]],
#                 (' Malad/Dindoshi/31/M03/', 0.9745116233825684)],
#                [[[1344.0, 526.0],
#                  [1466.0, 526.0],
#                  [1466.0, 563.0],
#                  [1344.0, 563.0]],
#                 (' Regular', 0.9771105051040649)],
#                [[[1661.0, 526.0],
#                  [1834.0, 526.0],
#                  [1834.0, 563.0],
#                  [1661.0, 563.0]],
#                 ('30-11-2023', 0.9989385604858398)],
#                [[[2007.0, 526.0],
#                  [2180.0, 526.0],
#                  [2180.0, 563.0],
#                  [2007.0, 563.0]],
#                 ('31-10-2023', 0.9975305795669556)],
#                [[[103.0, 548.0],
#                  [173.0, 548.0],
#                  [173.0, 588.0],
#                  [103.0, 588.0]],
#                 ('GST', 0.7288420796394348)],
#                [[[387.0, 727.0],
#                  [762.0, 727.0],
#                  [762.0, 764.0],
#                  [387.0, 764.0]],
#                 ('CA NO:153144669', 0.994805634021759)],
#                [[[851.0, 724.0],
#                  [1002.0, 724.0],
#                  [1002.0, 760.0],
#                  [851.0, 760.0]],
#                 ('Bill Month', 0.9972161054611206)],
#                [[[1341.0, 724.0],
#                  [1580.0, 724.0],
#                  [1580.0, 760.0],
#                  [1341.0, 760.0]],
#                 ('Units Consumed', 0.9998466372489929)],
#                [[[1672.0, 724.0],
#                  [1941.0, 724.0],
#                  [1941.0, 760.0],
#                  [1672.0, 760.0]],
#                 ('Current Month Bill', 0.9988548755645752)],
#                [[[2018.0, 724.0],
#                  [2328.0, 724.0],
#                  [2328.0, 760.0],
#                  [2018.0, 760.0]],
#                 ('Previous Outstanding', 0.9999074935913086)],
#                [[[851.0, 775.0],
#                  [998.0, 775.0],
#                  [998.0, 815.0],
#                  [851.0, 815.0]],
#                 ('NOV-23', 0.9945613741874695)],
#                [[[1344.0, 775.0],
#                  [1499.0, 775.0],
#                  [1499.0, 815.0],
#                  [1344.0, 815.0]],
#                 ('148260', 0.9999172687530518)],
#                [[[1676.0, 779.0],
#                  [1926.0, 779.0],
#                  [1926.0, 815.0],
#                  [1676.0, 815.0]],
#                 ('1759534.69', 0.9999176859855652)],
#                [[[2018.0, 779.0],
#                  [2210.0, 779.0],
#                  [2210.0, 815.0],
#                  [2018.0, 815.0]],
#                 ('17201.57', 0.9999442100524902)],
#                [[[387.0, 800.0],
#                  [751.0, 800.0],
#                  [751.0, 848.0],
#                  [387.0, 848.0]],
#                 ('1776840.00*', 0.9998316168785095)],
#                [[[854.0, 830.0],
#                  [1212.0, 830.0],
#                  [1212.0, 855.0],
#                  [854.0, 855.0]],
#                 ('Bill Period: 01-11-2023 - 30.11.2023', 0.9870011806488037)],
#                [[[1341.0, 826.0],
#                  [1598.0, 826.0],
#                  [1598.0, 863.0],
#                  [1341.0, 863.0]],
#                 (' Previous Units : 159900', 0.9833084940910339)],
#                [[[401.0, 910.0],
#                  [718.0, 910.0],
#                  [718.0, 958.0],
#                  [401.0, 958.0]],
#                 ('Due Date: 16-12-2023', 0.9974526166915894)],
#                [[[862.0, 947.0],
#                  [1956.0, 947.0],
#                  [1956.0, 972.0],
#                  [862.0, 972.0]],
#                 (': Round sum paybale by discount date 08-12-2023: Amt '
#                  '<1762710.00 Discount 14130.19',
#                  0.9819964170455933)],
#                [[[379.0, 987.0],
#                  [685.0, 987.0],
#                  [685.0, 1012.0],
#                  [379.0, 1012.0]],
#                 ('o only current bill amount', 0.9994534254074097)],
#                [[[862.0, 994.0],
#                  [1911.0, 994.0],
#                  [1911.0, 1031.0],
#                  [862.0, 1031.0]],
#                 (': Round sum paybale after due date 16-12-2023 : Amt '
#                  '<1798830.00# DPC <21994.18',
#                  0.9555148482322693)],
#                [[[122.0, 1005.0],
#                  [611.0, 1005.0],
#                  [611.0, 1042.0],
#                  [122.0, 1042.0]],
#                 ('previous balance is payable immediately',
#                  0.9995400905609131)],
#                [[[843.0, 1108.0],
#                  [1337.0, 1108.0],
#                  [1337.0, 1133.0],
#                  [843.0, 1133.0]],
#                 ('Nearest Collection Centre (Cash/Cheque)',
#                  0.9994735717773438)],
#                [[[136.0, 1118.0],
#                  [703.0, 1118.0],
#                  [703.0, 1155.0],
#                  [136.0, 1155.0]],
#                 ('Scan code to pay your bill via (use any UPI app)',
#                  0.9922091960906982)],
#                [[[2155.0, 1115.0],
#                  [2383.0, 1115.0],
#                  [2383.0, 1151.0],
#                  [2155.0, 1151.0]],
#                 ('Suhas Parab', 0.9720373749732971)],
#                [[[836.0, 1137.0],
#                  [1878.0, 1140.0],
#                  [1878.0, 1181.0],
#                  [836.0, 1177.0]],
#                 ('Adani Electricity, Malad, MBH colony, Dindoshi, Western '
#                  'Express Highway.',
#                  0.9944779276847839)],
#                [[[129.0, 1166.0],
#                  [250.0, 1166.0],
#                  [250.0, 1206.0],
#                  [129.0, 1206.0]],
#                 ('LPIT', 0.6758822798728943)],
#                [[[291.0, 1166.0],
#                  [471.0, 1166.0],
#                  [471.0, 1203.0],
#                  [291.0, 1203.0]],
#                 ('BBPS', 0.7704920768737793)],
#                [[[556.0, 1162.0],
#                  [711.0, 1162.0],
#                  [711.0, 1203.0],
#                  [107.0, 2105.0]],
#                 ('Borivali West, Mumbai 400 103', 0.9597265720367432)],
#                [[[1540.0, 2087.0],
#                  [1867.0, 2087.0],
#                  [1867.0, 2124.0],
#                  [1540.0, 2124.0]],
#                 ('19122 Toll Free No.(24X7)', 0.9864570498466492)],
#                [[[1878.0, 2091.0],
#                  [2265.0, 2091.0],
#                  [2265.0, 2127.0],
#                  [1878.0, 2127.0]],
#                 ('www.adanielectricity.com', 0.9994973540306091)],
#                [[[103.0, 2131.0],
#                  [748.0, 2131.0],
#                  [748.0, 2168.0],
#                  [103.0, 2168.0]],
#                 ('Email: consumerforum.mumbaielectricity@adani.com',
#                  0.9931126236915588)],
#                [[[810.0, 2131.0],
#                  [1234.0, 2131.0],
#                  [1234.0, 2168.0],
#                  [810.0, 2168.0]],
#                 ('Website: cgrf.adanielectricity.com', 0.9998195767402649)],
#                [[[1543.0, 2157.0],
#                  [2018.0, 2157.0],
#                  [2018.0, 2182.0],
#                  [1543.0, 2182.0]],
#                 ('helpdesk.mumbaielectricity@adani.com', 0.9969017505645752)],
#                [[[103.0, 2179.0],
#                  [387.0, 2179.0],
#                  [387.0, 2215.0],
#                  [103.0, 2215.0]],
#                 ('Phone: 022-50745004', 0.9997971057891846)],
#                [[[1518.0, 2208.0],
#                  [2313.0, 2211.0],
#                  [2313.0, 2252.0],
#                  [1517.0, 2248.0]],
#                 ('Adani Electricity, Malad, MBH colony, Dindoshi, Western '
#                  'Express',
#                  0.9840930104255676)],
#                [[[1547.0, 2237.0],
#                  [2022.0, 2237.0],
#                  [2022.0, 2274.0],
#                  [1547.0, 2274.0]],
#                 ('Highway, Malad(East), Mumbai-400097', 0.980057418346405)],
#                [[[99.0, 2303.0],
#                  [486.0, 2303.0],
#                  [486.0, 2339.0],
#                  [99.0, 2339.0]],
#                 ('REGISTERED OFFICE AEML', 0.9977062344551086)],
#                [[[1495.0, 2317.0],
#                  [2144.0, 2317.0],
#                  [2144.0, 2343.0],
#                  [1495.0, 2343.0]],
#                 ('For power interruption complaint or restoration status',
#                  0.9988179206848145)],
#                [[[1481.0, 2339.0],
#                  [2291.0, 2343.0],
#                  [2291.0, 2391.0],
#                  [1480.0, 2387.0]],
#                 ('SMS POwER<9 digit account no.> to 7065313030 from mobile no.',
#                  0.9820628762245178)],
#                [[[118.0, 2391.0],
#                  [490.0, 2391.0],
#                  [490.0, 2416.0],
#                  [118.0, 2416.0]],
#                 ('Address: Adani Corporate Hous', 0.9988996386528015)],
#                [[[497.0, 2387.0],
#                  [1260.0, 2387.0],
#                  [1260.0, 2423.0],
#                  [497.0, 2423.0]],
#                 ('e, Shantigram, Near Vaishno Devi Circle, S. G. Highway, '
#                  'Khodiyar.',
#                  0.9863370656967163)],
#                [[[1488.0, 2383.0],
#                  [2365.0, 2383.0],
#                  [2365.0, 2420.0],
#                  [1488.0, 2420.0]],
#                 ('Whatsapp P0wER <9 digit account no> to 9594519122 from any '
#                  'mobile',
#                  0.9827437400817871)],
#                [[[114.0, 2412.0],
#                  [534.0, 2412.0],
#                  [534.0, 2449.0],
#                  [114.0, 2449.0]],
#                 ('Ahmedabad, Gujarat, India-382421', 0.9993739128112793)],
#                [[[1484.0, 2456.0],
#                  [2335.0, 2456.0],
#                  [2335.0, 2493.0],
#                  [1484.0, 2493.0]],
#                 ('Give us missed call on 1800 532 9998 from your registered '
#                  'mobile no.',
#                  0.9996885657310486)],
#                [[[114.0, 2482.0],
#                  [516.0, 2482.0],
#                  [516.0, 2518.0],
#                  [114.0, 2518.0]],
#                 ('CIN: U74999GJ2008PLC107256', 0.9942387938499451)],
#                [[[586.0, 2482.0],
#                  [832.0, 2482.0],
#                  [832.0, 2518.0],
#                  [586.0, 2518.0]],
#                 ('PAN: AADCD0086F', 0.9764381647109985)],
#                [[[939.0, 2482.0],
#                  [1285.0, 2482.0],
#                  [1285.0, 2518.0],
#                  [939.0, 2518.0]],
#                 ('GSTIN: 27AADCD0086F1ZW', 0.9793115854263306)],
#                [[[1488.0, 2497.0],
#                  [1956.0, 2497.0],
#                  [1956.0, 2533.0],
#                  [1488.0, 2533.0]],
#                 ('Portal Related Complaint call us:19122', 0.9881892204284668)],
#                [[[1492.0, 2548.0],
#                  [2250.0, 2548.0],
#                  [2250.0, 2573.0],
#                  [1492.0, 2573.0]],
#                 ('For internal complaint redressal system(IcRs), visit our '
#                  'website:',
#                  0.981613039970398)],
#                [[[1672.0, 2621.0],
#                  [1713.0, 2621.0],
#                  [1713.0, 2650.0],
#                  [1672.0, 2650.0]],
#                 ('f', 0.9392310976982117)],
#                [[[1709.0, 2617.0],
#                  [1904.0, 2617.0],
#                  [1904.0, 2654.0],
#                  [1709.0, 2654.0]],
#                 ('Ono', 0.630662202835083)],
#                [[[1506.0, 2628.0],
#                  [1639.0, 2628.0],
#                  [1639.0, 2665.0],
#                  [1506.0, 2665.0]],
#                 ('Join us on:', 0.9963953495025635)],
#                [[[107.0, 2654.0],
#                  [438.0, 2654.0],
#                  [438.0, 2690.0],
#                  [107.0, 2690.0]],
#                 ('IMPORTANT MESSAGE', 0.9988096952438354)],
#                [[[96.0, 2730.0],
#                  [972.0, 2730.0],
#                  [972.0, 2767.0],
#                  [96.0, 2767.0]],
#                 ('o Please pay this bill by Online / RTGS / NEFT / Cheque or '
#                  'Demand Draft.',
#                  0.9627164006233215)],
#                [[[1528.0, 2767.0],
#                  [2324.0, 2767.0],
#                  [2324.0, 2815.0],
#                  [1528.0, 2815.0]],
#                 ('Special Summary Revision Programme 2024',
#                  0.9977104067802429)],
#                [[[92.0, 2818.0],
#                  [1366.0, 2818.0],
#                  [1366.0, 2855.0],
#                  [92.0, 2855.0]],
#                 ('o W.e.f 1st April 2022 TCS @ O.1% is applicable on '
#                  'collection amount exceeding Rs.50 Lakh. TCS at penal',
#                  0.9850409626960754)],
#                [[[125.0, 2847.0],
#                  [1112.0, 2847.0],
#                  [1112.0, 2884.0],
#                  [125.0, 2884.0]],
#                 ('rate is applicable for no PAN and u/s. 206cCA for non-filing '
#                  'of Income Tax Return',
#                  0.9844062924385071)],
#                [[[2017.0, 2852.0],
#                  [2170.0, 2835.0],
#                  [2175.0, 2875.0],
#                  [2021.0, 2893.0]],
#                 ('cember2023', 0.9905464053153992)],
#                [[[92.0, 2906.0],
#                  [1333.0, 2906.0],
#                  [1333.0, 2942.0],
#                  [92.0, 2942.0]],
#                 ('O In view of MERC order in case no. 325 of 2019, cash '
#                  'payment limit towards electricity bills is fixed at',
#                  0.9849221110343933)],
#                [[[1576.0, 2924.0],
#                  [2269.0, 2924.0],
#                  [2269.0, 2972.0],
#                  [1576.0, 2972.0]],
#                 ('For an energy-efficient democracy,', 0.9938309788703918)],
#                [[[118.0, 2935.0],
#                  [1238.0, 2935.0],
#                  [1238.0, 2972.0],
#                  [118.0, 2972.0]],
#                 ('Rs.5,ooo/- per account per month. For payment of amount '
#                  'greater than Rs.5,ooo please use',
#                  0.9863075613975525)],
#                [[[122.0, 2961.0],
#                  [755.0, 2961.0],
#                  [755.0, 2997.0],
#                  [122.0, 2997.0]],
#                 ('convenient digital channels / online / cheque modes',
#                  0.9995384812355042)],
#                [[[1709.0, 2968.0],
#                  [2144.0, 2968.0],
#                  [2144.0, 3005.0],
#                  [1709.0, 3005.0]],
#                 ("let's register as voters", 0.9567295908927917)],
#                [[[92.0, 2997.0],
#                  [1020.0, 2997.0],
#                  [1020.0, 3034.0],
#                  [92.0, 3034.0]],
#                 ('o Meter reading as on O1.01.24 will be downloaded for '
#                  'preparing DEC-23 bill',
#                  0.9797577857971191)],
#                [[[1731.0, 3001.0],
#                  [2125.0, 3005.0],
#                  [2125.0, 3052.0],
#                  [1731.0, 3048.0]],
#                 ('and fulfill your duty.', 0.9841277599334717)],
#                [[[1683.0, 3052.0],
#                  [2169.0, 3052.0],
#                  [2169.0, 3089.0],
#                  [1683.0, 3089.0]],
#                 ('Do check your name in the voter list.', 0.9855927228927612)],
#                [[[1624.0, 3081.0],
#                  [2225.0, 3081.0],
#                  [2225.0, 3118.0],
#                  [1624.0, 3118.0]],
#                 ("If it's not there, register yourself immediately.",
#                  0.9825847148895264)],
#                [[[1915.0, 3180.0],
#                  [2055.0, 3180.0],
#                  [2055.0, 3206.0],
#                  [1915.0, 3206.0]],
#                 ('egistratior', 0.9951164722442627)],
#                [[[1749.0, 3209.0],
#                  [2092.0, 3209.0],
#                  [2092.0, 3246.0],
#                  [1749.0, 3246.0]],
#                 ('visit voters.eci.gov.in', 0.9772021174430847)],
#                [[[2180.0, 3290.0],
#                  [2243.0, 3290.0],
#                  [2243.0, 3315.0],
#                  [2180.0, 3315.0]],
#                 ('DE', 0.6341254711151123)],
#                [[[1536.0, 3326.0],
#                  [1665.0, 3326.0],
#                  [1665.0, 3366.0],
#                  [1536.0, 3366.0]],
#                 ('Google Play', 0.8454246520996094)],
#                [[[2180.0, 3319.0],
#                  [2328.0, 3319.0],
#                  [2328.0, 3370.0],
#                  [2180.0, 3370.0]],
#                 ('App Store', 0.9049370884895325)],
#                [[[1783.0, 3334.0],
#                  [2074.0, 3334.0],
#                  [2074.0, 3370.0],
#                  [1783.0, 3370.0]],
#                 ('Voter Helpline app.', 0.9883732795715332)],
#                [[[2265.0, 3432.0],
#                  [2365.0, 3432.0],
#                  [2365.0, 3472.0],
#                  [2265.0, 3472.0]],
#                 ('E.&0.E', 0.922028124332428)],
#                [[[1436.0, 3443.0],
#                  [2074.0, 3443.0],
#                  [2074.0, 3480.0],
#                  [1436.0, 3480.0]],
#                 ('Dt.31/12/2027). OW4819 Dated 29/11/2023, GRN NO.',
#                  0.9960966110229492)],
#                [[[114.0, 3472.0],
#                  [564.0, 3472.0],
#                  [564.0, 3498.0],
#                  [114.0, 3498.0]],
#                 ('MH010146824202324E, DATE:27/10/', 0.9874703288078308)]]]},
#  {'image': 'Adani_Commercial_HT_II_page_2.png',
#   'image_height': 3509,
#   'image_width': 2475,
#   'ocrdata': [[[[[1481.0, 29.0],
#                  [2342.0, 29.0],
#                  [2342.0, 66.0],
#                  [1481.0, 66.0]],
#                 ('YOUR TARIFF STRUCTURE (EFFECTIVE FROM O1.O4.2023) ',
#                  0.9752840399742126)],
#                [[[103.0, 40.0], [619.0, 40.0], [619.0, 77.0], [103.0, 77.0]],
#                 ('HOW YOUR BILL WAS CALCULATED', 0.996881902217865)],
#                [[[88.0, 117.0], [192.0, 117.0], [192.0, 157.0], [88.0, 157.0]],
#                 ('Heads', 0.9998343586921692)],
#                [[[983.0, 117.0],
#                  [1153.0, 117.0],
#                  [1153.0, 157.0],
#                  [983.0, 157.0]],
#                 ('Rate/Tariff', 0.9998041391372681)],
#                [[[1267.0, 117.0],
#                  [1403.0, 117.0],
#                  [1403.0, 157.0],
#                  [1267.0, 157.0]],
#                 ('INR(<)', 0.8609780669212341)],
#                [[[1484.0, 113.0],
#                  [1562.0, 113.0],
#                  [1562.0, 154.0],
#                  [1484.0, 154.0]],
#                 ('HT I', 0.9002164006233215)],
#                [[[1794.0, 117.0],
#                  [1882.0, 117.0],
#                  [1882.0, 157.0],
#                  [1794.0, 157.0]],
#                 ('Fixed', 0.9995091557502747)],
#                [[[1936.0, 112.0],
#                  [2038.0, 122.0],
#                  [2034.0, 162.0],
#                  [1932.0, 152.0]],
#                 ('Energy', 0.9994938969612122)],
#                [[[2077.0, 117.0],
#                  [2339.0, 117.0],
#                  [2339.0, 157.0],
#                  [2077.0, 157.0]],
#                 ('Wheeling FAC Rate', 0.9524276852607727)],
#                [[[1485.0, 150.0],
#                  [1669.0, 154.0],
#                  [1668.0, 194.0],
#                  [1484.0, 190.0]],
#                 (' COMMERCIAL', 0.9599370956420898)],
#                [[[1794.0, 154.0],
#                  [1897.0, 154.0],
#                  [1897.0, 194.0],
#                  [1794.0, 194.0]],
#                 ('Charge', 0.9998042583465576)],
#                [[[1936.0, 149.0],
#                  [2034.0, 158.0],
#                  [2030.0, 199.0],
#                  [1932.0, 189.0]],
#                 ('Charge', 0.9998515248298645)],
#                [[[2077.0, 154.0],
#                  [2177.0, 154.0],
#                  [2177.0, 194.0],
#                  [2077.0, 194.0]],
#                 ('Charge', 0.9997536540031433)],
#                [[[2216.0, 149.0],
#                  [2314.0, 158.0],
#                  [2310.0, 199.0],
#                  [2212.0, 189.0]],
#                 ('Charge', 0.9543125629425049)],
#                [[[114.0, 179.0],
#                  [678.0, 179.0],
#                  [678.0, 216.0],
#                  [114.0, 216.0]],
#                 ('Electrical Energy (HSN Code 27160000)', 0.9855678677558899)],
#                [[[1482.0, 189.0],
#                  [1654.0, 198.0],
#                  [1652.0, 238.0],
#                  [1480.0, 230.0]],
#                 ('Units/Month', 0.9998345971107483)],
#                [[[1794.0, 197.0],
#                  [1904.0, 197.0],
#                  [1904.0, 238.0],
#                  [1794.0, 238.0]],
#                 ('Per kVA', 0.9997366666793823)],
#                [[[1932.0, 193.0],
#                  [2049.0, 202.0],
#                  [2046.0, 242.0],
#                  [1929.0, 233.0]],
#                 (' Per Unit', 0.9842783808708191)],
#                [[[2068.0, 189.0],
#                  [2196.0, 198.0],
#                  [2193.0, 238.0],
#                  [2065.0, 229.0]],
#                 (' Per Unit', 0.9535281658172607)],
#                [[[2208.0, 189.0],
#                  [2321.0, 198.0],
#                  [2318.0, 239.0],
#                  [2205.0, 229.0]],
#                 ('NOV-23', 0.9914900660514832)],
#                [[[92.0, 241.0], [442.0, 241.0], [442.0, 278.0], [92.0, 278.0]],
#                 ('1. Demand/Fixed Charge', 0.9998845458030701)],
#                [[[1238.0, 241.0],
#                  [1407.0, 241.0],
#                  [1407.0, 278.0],
#                  [1238.0, 278.0]],
#                 ('254250.00', 0.9998591542243958)],
#                [[[1488.0, 245.0],
#                  [1602.0, 245.0],
#                  [1602.0, 285.0],
#                  [1488.0, 285.0]],
#                 ('All Units', 0.9977614283561707)],
#                [[[1794.0, 245.0],
#                  [1897.0, 245.0],
#                  [1897.0, 281.0],
#                  [1794.0, 281.0]],
#                 ('375.00', 0.9997968077659607)],
#                [[[1934.0, 245.0],
#                  [2004.0, 245.0],
#                  [2004.0, 285.0],
#                  [1934.0, 285.0]],
#                 ('6.70', 0.999708354473114)],
#                [[[2074.0, 245.0],
#                  [2147.0, 245.0],
#                  [2147.0, 285.0],
#                  [2074.0, 285.0]],
#                 ('0.97', 0.9998519420623779)],
#                [[[89.0, 289.0], [387.0, 293.0], [386.0, 333.0], [88.0, 329.0]],
#                 ('2. Wheeling Charges', 0.9864532351493835)],
#                [[[1488.0, 285.0],
#                  [1738.0, 285.0],
#                  [1738.0, 322.0],
#                  [1488.0, 322.0]],
#                 (' 06:00 to 09:00 Hrs', 0.9786516427993774)],
#                [[[1934.0, 281.0],
#                  [2011.0, 281.0],
#                  [2011.0, 322.0],
#                  [1934.0, 322.0]],
#                 ('0.00', 0.9997823238372803)],
#                [[[1245.0, 292.0],
#                  [1407.0, 292.0],
#                  [1407.0, 329.0],
#                  [1245.0, 329.0]],
#                 ('143812.20', 0.9999392628669739)],
#                [[[1488.0, 318.0],
#                  [1735.0, 322.0],
#                  [1734.0, 362.0],
#                  [1488.0, 358.0]],
#                 (' 09:00 to 12:00 Hrs', 0.9811258912086487)],
#                [[[1934.0, 322.0],
#                  [2007.0, 322.0],
#                  [2007.0, 362.0],
#                  [1934.0, 362.0]],
#                 ('0.50', 0.9998174905776978)],
#                [[[92.0, 347.0], [475.0, 347.0], [475.0, 384.0], [92.0, 384.0]],
#                 ('3. Regulatory Asset Charge', 0.9998044371604919)],
#                [[[1322.0, 340.0],
#                  [1407.0, 340.0],
#                  [1407.0, 380.0],
#                  [1322.0, 380.0]],
#                 ('0.00', 0.9998070001602173)],
#                [[[1492.0, 362.0],
#                  [1727.0, 362.0],
#                  [1727.0, 398.0],
#                  [1492.0, 398.0]],
#                 ('12:00 to 18:00 Hrs', 0.9995659589767456)],
#                [[[1934.0, 362.0],
#                  [2007.0, 362.0],
#                  [2007.0, 402.0],
#                  [1934.0, 402.0]],
#                 ('0.00', 0.9998672008514404)],
#                [[[93.0, 395.0], [343.0, 399.0], [342.0, 439.0], [92.0, 435.0]],
#                 ('4. Energy Charge', 0.9995210766792297)],
#                [[[1238.0, 398.0],
#                  [1407.0, 398.0],
#                  [1407.0, 435.0],
#                  [1238.0, 435.0]],
#                 ('993342.00', 0.9999121427536011)],
#                [[[1492.0, 402.0],
#                  [1735.0, 402.0],
#                  [1735.0, 439.0],
#                  [1492.0, 439.0]],
#                 ('18:00 to 22:00 Hrs', 0.9996342062950134)],
#                [[[1934.0, 402.0],
#                  [2007.0, 402.0],
#                  [2007.0, 442.0],
#                  [1934.0, 442.0]],
#                 ('1.00', 0.9918801188468933)],
#                [[[1492.0, 446.0],
#                  [1727.0, 446.0],
#                  [1727.0, 472.0],
#                  [1492.0, 472.0]],
#                 ('22:00 to 06:00 Hrs', 0.9947206974029541)],
#                [[[1937.0, 439.0],
#                  [2011.0, 439.0],
#                  [2011.0, 479.0],
#                  [1937.0, 479.0]],
#                 ('0.75-', 0.9958173036575317)],
#                [[[96.0, 450.0], [619.0, 450.0], [619.0, 486.0], [96.0, 486.0]],
#                 ('5. T0D 9 Hrs to 12 Hrs energy charge', 0.9750031232833862)],
#                [[[1256.0, 450.0],
#                  [1411.0, 450.0],
#                  [1411.0, 486.0],
#                  [1256.0, 486.0]],
#                 ('16530.00', 0.9997129440307617)],
#                [[[1263.0, 501.0],
#                  [1407.0, 501.0],
#                  [1407.0, 541.0],
#                  [1263.0, 541.0]],
#                 ('17100.00', 0.9998361468315125)],
#                [[[92.0, 504.0], [637.0, 504.0], [637.0, 541.0], [92.0, 541.0]],
#                 ('6. T0D 18 Hrs to 22 Hrs energy charge', 0.9890894293785095)],
#                [[[92.0, 556.0], [641.0, 556.0], [641.0, 592.0], [92.0, 592.0]],
#                 ('7. T0D 22 Hrs to 06 Hrs energy charge', 0.9886696338653564)],
#                [[[1234.0, 556.0],
#                  [1407.0, 556.0],
#                  [1407.0, 592.0],
#                  [1234.0, 592.0]],
#                 ('12015.00Cr', 0.9988792538642883)],
#                [[[980.0, 607.0],
#                  [1064.0, 607.0],
#                  [1064.0, 647.0],
#                  [980.0, 647.0]],
#                 ('0.00', 0.9998118877410889)],
#                [[[1322.0, 598.0],
#                  [1408.0, 608.0],
#                  [1404.0, 648.0],
#                  [1317.0, 638.0]],
#                 ('0.00', 0.9998747706413269)],
#                [[[92.0, 610.0], [427.0, 610.0], [427.0, 647.0], [92.0, 647.0]],
#                 ('8. Fuel Adj. Chg (FAC)#', 0.9957053065299988)],
#                [[[1484.0, 636.0],
#                  [2254.0, 636.0],
#                  [2254.0, 673.0],
#                  [1484.0, 673.0]],
#                 ('YOU CAN USE RTGS/NEFT VIA NETBANKING FOR BILL',
#                  0.9992702007293701)],
#                [[[92.0, 662.0], [689.0, 662.0], [689.0, 698.0], [92.0, 698.0]],
#                 ('9. Penalty for exceeding contract demand',
#                  0.9844913482666016)],
#                [[[1322.0, 658.0],
#                  [1411.0, 658.0],
#                  [1411.0, 698.0],
#                  [1322.0, 698.0]],
#                 ('0.00', 0.9995942115783691)],
#                [[[92.0, 713.0], [656.0, 713.0], [656.0, 749.0], [92.0, 749.0]],
#                 ('10. Power Factor (PF) penalty/incentive',
#                  0.9980892539024353)],
#                [[[1319.0, 709.0],
#                  [1411.0, 709.0],
#                  [1411.0, 749.0],
#                  [1319.0, 749.0]],
#                 ('0.00', 0.9993963837623596)],
#                [[[1484.0, 738.0],
#                  [2007.0, 738.0],
#                  [2007.0, 775.0],
#                  [1484.0, 775.0]],
#                 (' Payment Account No : EPAEML153144669', 0.9935095310211182)],
#                [[[92.0, 768.0], [541.0, 768.0], [541.0, 804.0], [92.0, 804.0]],
#                 ('11. Government Electricity Duty', 0.9995900988578796)],
#                [[[983.0, 764.0],
#                  [1098.0, 764.0],
#                  [1098.0, 804.0],
#                  [983.0, 804.0]],
#                 ('21.00%', 0.9999625086784363)],
#                [[[1241.0, 764.0],
#                  [1411.0, 764.0],
#                  [1411.0, 800.0],
#                  [1241.0, 800.0]],
#                 ('296734.03', 0.9998369216918945)],
#                [[[1488.0, 790.0],
#                  [2062.0, 790.0],
#                  [2062.0, 826.0],
#                  [1488.0, 826.0]],
#                 ('Payee Name : Adani Electricity Mumbai Limited',
#                  0.9908366799354553)],
#                [[[92.0, 819.0], [633.0, 819.0], [633.0, 855.0], [92.0, 855.0]],
#                 ('12. Mah Govt Tax on sale of electricity', 0.98862624168396)],
#                [[[983.0, 819.0],
#                  [1215.0, 819.0],
#                  [1215.0, 855.0],
#                  [983.0, 855.0]],
#                 ('34.04p/kWh ##', 0.9757956266403198)],
#                [[[1256.0, 819.0],
#                  [1411.0, 819.0],
#                  [1411.0, 855.0],
#                  [1256.0, 855.0]],
#                 ('49781.46', 0.9998791813850403)],
#                [[[1488.0, 837.0],
#                  [1775.0, 837.0],
#                  [1775.0, 874.0],
#                  [1488.0, 874.0]],
#                 ('Account Type : Current', 0.9984170794487)],
#                [[[1934.0, 833.0],
#                  [2206.0, 833.0],
#                  [2206.0, 870.0],
#                  [1934.0, 870.0]],
#                 ('IFSC : HDFC0004989', 0.9849454164505005)],
#                [[[92.0, 870.0], [726.0, 870.0], [726.0, 906.0], [92.0, 906.0]],
#                 ("(A) Current month's bill amount (Sum of 1-12)",
#                  0.9961327314376831)],
#                [[[1223.0, 870.0],
#                  [1407.0, 870.0],
#                  [1407.0, 906.0],
#                  [1223.0, 906.0]],
#                 ('1759534.69', 0.999891459941864)],
#                [[[1488.0, 885.0],
#                  [2040.0, 885.0],
#                  [2040.0, 921.0],
#                  [1488.0, 921.0]],
#                 ('Branch Name : Kanjurmarg Branch, Mumbai', 0.989831268787384)],
#                [[[2026.0, 885.0],
#                  [2387.0, 885.0],
#                  [2387.0, 921.0],
#                  [2026.0, 921.0]],
#                 ('Bank Name : HDFC Bank Ltd.', 0.9943491220474243)],
#                [[[96.0, 925.0], [401.0, 925.0], [401.0, 961.0], [96.0, 961.0]],
#                 ('a. Others /SD interest', 0.9988448619842529)],
#                [[[1322.0, 921.0],
#                  [1411.0, 921.0],
#                  [1411.0, 961.0],
#                  [1322.0, 961.0]],
#                 ('0.00', 0.9996719360351562)],
#                [[[92.0, 976.0],
#                  [663.0, 976.0],
#                  [663.0, 1012.0],
#                  [92.0, 1012.0]],
#                 ('b. Delayed Payment Charge (DPc) levied', 0.9733117818832397)],
#                [[[1300.0, 972.0],
#                  [1411.0, 972.0],
#                  [1411.0, 1012.0],
#                  [1300.0, 1012.0]],
#                 ('107.49', 0.9998812079429626)],
#                [[[1484.0, 987.0],
#                  [1970.0, 987.0],
#                  [1970.0, 1023.0],
#                  [1484.0, 1023.0]],
#                 ('ADVANCE PAYMENT DETAILS ()', 0.9915642142295837)],
#                [[[92.0, 1027.0],
#                  [486.0, 1027.0],
#                  [486.0, 1064.0],
#                  [92.0, 1064.0]],
#                 ('c. Digital Payment Discount', 0.993453860282898)],
#                [[[1322.0, 1023.0],
#                  [1411.0, 1023.0],
#                  [1411.0, 1064.0],
#                  [1322.0, 1064.0]],
#                 ('0.00', 0.9995194673538208)],
#                [[[92.0, 1082.0],
#                  [398.0, 1082.0],
#                  [398.0, 1118.0],
#                  [92.0, 1118.0]],
#                 ('d. Interest on Arrears', 0.9988519549369812)],
#                [[[1319.0, 1078.0],
#                  [1411.0, 1078.0],
#                  [1411.0, 1118.0],
#                  [1319.0, 1118.0]],
#                 ('0.00', 0.9996912479400635)],
#                [[[1484.0, 1097.0],
#                  [1665.0, 1097.0],
#                  [1665.0, 1133.0],
#                  [1484.0, 1133.0]],
#                 (' Opening Balance', 0.9842455387115479)],
#                [[[1709.0, 1097.0],
#                  [1849.0, 1097.0],
#                  [1849.0, 1133.0],
#                  [1709.0, 1133.0]],
#                 ('Adjustments', 0.9997181296348572)],
#                [[[1934.0, 1093.0],
#                  [2029.0, 1093.0],
#                  [2029.0, 1133.0],
#                  [1934.0, 1133.0]],
#                 ('Interest', 0.9832855463027954)],
#                [[[2162.0, 1097.0],
#                  [2331.0, 1097.0],
#                  [2331.0, 1133.0],
#                  [2162.0, 1133.0]],
#                 (' Closing Balance', 0.9748868942260742)],
#                [[[92.0, 1133.0],
#                  [313.0, 1133.0],
#                  [313.0, 1170.0],
#                  [92.0, 1170.0]],
#                 ('e. Adjustments', 0.9995452165603638)],
#                [[[1319.0, 1129.0],
#                  [1407.0, 1129.0],
#                  [1407.0, 1170.0],
#                  [1319.0, 1170.0]],
#                 ('0.00', 0.9998196959495544)],
#                [[[89.0, 1181.0],
#                  [807.0, 1184.0],
#                  [806.0, 1225.0],
#                  [88.0, 1221.0]],
#                 ('(B) Net other charges In current bill (Sum of a to e)',
#                  0.9960286617279053)],
#                [[[1293.0, 1184.0],
#                  [1407.0, 1184.0],
#                  [1407.0, 1224.0],
#                  [1293.0, 1224.0]],
#                 ('107.49', 0.9999008178710938)],
#                [[[1484.0, 1210.0],
#                  [1948.0, 1210.0],
#                  [1948.0, 1246.0],
#                  [1484.0, 1246.0]],
# ...
#                 ('Meter Details', 0.999737024307251)],
#                [[[420.0, 2226.0],
#                  [549.0, 2226.0],
#                  [549.0, 2263.0],
#                  [420.0, 2263.0]],
#                 ('Meter No', 0.9987059235572815)],
#                [[[983.0, 2222.0],
#                  [1105.0, 2222.0],
#                  [1105.0, 2263.0],
#                  [983.0, 2263.0]],
#                 ('H953181', 0.9998616576194763)],
#                [[[2313.0, 2222.0],
#                  [2390.0, 2222.0],
#                  [2390.0, 2263.0],
#                  [2313.0, 2263.0]],
#                 ('Total', 0.9991099238395691)],
#                [[[424.0, 2274.0],
#                  [652.0, 2274.0],
#                  [652.0, 2310.0],
#                  [424.0, 2310.0]],
#                 (' Multiplying Factor', 0.9785838723182678)],
#                [[[1020.0, 2270.0],
#                  [1109.0, 2270.0],
#                  [1109.0, 2310.0],
#                  [1020.0, 2310.0]],
#                 ('6000', 0.9996023178100586)],
#                [[[88.0, 2321.0],
#                  [306.0, 2321.0],
#                  [306.0, 2358.0],
#                  [88.0, 2358.0]],
#                 (' Energy Consumption', 0.9759179949760437)],
#                [[[419.0, 2313.0],
#                  [521.0, 2322.0],
#                  [517.0, 2362.0],
#                  [415.0, 2353.0]],
#                 (' Reading', 0.9792430400848389)],
#                [[[740.0, 2321.0],
#                  [843.0, 2321.0],
#                  [843.0, 2358.0],
#                  [740.0, 2358.0]],
#                 ('Present', 0.9988642334938049)],
#                [[[1013.0, 2317.0],
#                  [1105.0, 2317.0],
#                  [1105.0, 2358.0],
#                  [1013.0, 2358.0]],
#                 ('2259.72', 0.9999367594718933)],
#                [[[748.0, 2361.0],
#                  [851.0, 2361.0],
#                  [851.0, 2401.0],
#                  [748.0, 2401.0]],
#                 (' Previous', 0.9518627524375916)],
#                [[[1017.0, 2369.0],
#                  [1109.0, 2369.0],
#                  [1109.0, 2401.0],
#                  [1017.0, 2401.0]],
#                 ('2235.01', 0.9998404383659363)],
#                [[[424.0, 2412.0],
#                  [641.0, 2412.0],
#                  [641.0, 2449.0],
#                  [424.0, 2449.0]],
#                 ('Consumption (kVAh)', 0.9974494576454163)],
#                [[[1013.0, 2409.0],
#                  [419.0, 2901.0]],
#                 ('Reading', 0.9980541467666626)],
#                [[[1035.0, 2866.0],
#                  [1109.0, 2866.0],
#                  [1109.0, 2906.0],
#                  [1035.0, 2906.0]],
#                 ('0.113', 0.9979001879692078)],
#                [[[92.0, 2917.0],
#                  [291.0, 2917.0],
#                  [291.0, 2953.0],
#                  [92.0, 2953.0]],
#                 ('(Recorded between', 0.9996934533119202)],
#                [[[92.0, 2961.0],
#                  [295.0, 2961.0],
#                  [295.0, 2997.0],
#                  [92.0, 2997.0]],
#                 ('06:00 - 22:00 Hrs)', 0.9802865982055664)],
#                [[[424.0, 2961.0],
#                  [530.0, 2961.0],
#                  [530.0, 3001.0],
#                  [424.0, 3001.0]],
#                 ('MD (kVA)', 0.9927131533622742)],
#                [[[1016.0, 2952.0],
#                  [1110.0, 2962.0],
#                  [1105.0, 3006.0],
#                  [1011.0, 2996.0]],
#                 ('678.00', 0.9997581839561462)],
#                [[[2306.0, 2961.0],
#                  [2394.0, 2961.0],
#                  [2394.0, 3001.0],
#                  [2306.0, 3001.0]],
#                 ('678.00', 0.9997652173042297)],
#                [[[419.0, 2996.0],
#                  [521.0, 3006.0],
#                  [516.0, 3050.0],
#                  [415.0, 3040.0]],
#                 (' Reading', 0.9832566976547241)],
#                [[[92.0, 3008.0],
#                  [291.0, 3008.0],
#                  [291.0, 3045.0],
#                  [92.0, 3045.0]],
#                 ('Max demand (MD)', 0.9932531118392944)],
#                [[[1035.0, 3005.0],
#                  [1109.0, 3005.0],
#                  [1109.0, 3045.0],
#                  [1035.0, 3045.0]],
#                 ('0.113', 0.998779296875)],
#                [[[89.0, 3048.0],
#                  [295.0, 3052.0],
#                  [294.0, 3093.0],
#                  [88.0, 3088.0]],
#                 ('(Recorded between', 0.9662133455276489)],
#                [[[92.0, 3100.0],
#                  [298.0, 3100.0],
#                  [298.0, 3136.0],
#                  [92.0, 3136.0]],
#                 (' 00:00 - 24:00 Hrs)', 0.9877650737762451)],
#                [[[424.0, 3096.0],
#                  [534.0, 3096.0],
#                  [534.0, 3136.0],
#                  [424.0, 3136.0]],
#                 ('MD (kVA)', 0.9891523718833923)],
#                [[[1017.0, 3096.0],
#                  [1109.0, 3096.0],
#                  [1109.0, 3136.0],
#                  [1017.0, 3136.0]],
#                 ('678.00', 0.9997131824493408)],
#                [[[2306.0, 3096.0],
#                  [2394.0, 3096.0],
#                  [2394.0, 3136.0],
#                  [2306.0, 3136.0]],
#                 ('678.00', 0.9996498227119446)],
#                [[[419.0, 3135.0],
#                  [521.0, 3145.0],
#                  [516.0, 3188.0],
#                  [415.0, 3179.0]],
#                 (' Reading', 0.9629284143447876)],
#                [[[92.0, 3147.0],
#                  [265.0, 3147.0],
#                  [265.0, 3184.0],
#                  [92.0, 3184.0]],
#                 (' Reactive energy', 0.9755393266677856)],
#                [[[744.0, 3147.0],
#                  [843.0, 3147.0],
#                  [843.0, 3184.0],
#                  [744.0, 3184.0]],
#                 (' Present', 0.9603052139282227)],
#                 ('Billing demand is 678.00 kVA Actual Maximum Demand recorded '
#                  'in the month during 0600 hours to 2200 hours',
#                  0.9912800192832947)]]]}]

# %% [markdown]
# #### Transform core pocr data into normalised bbox

# %%
bill_ocr_data = []

for data_dict in page_data:
    transform_data = {}
    image_width = data_dict["image_width"]
    image_height = data_dict["image_height"]
    image = data_dict["image"]
    ocrdata = data_dict["ocrdata"]
    ocr_box = []
    for box, (text, confidence) in ocrdata[0]:
        four_co_ord = [box[0][0],box[1][1],box[2][0]-box[0][0],box[2][1]-box[1][1]]
        target_bbox = {
            'x': 100 * four_co_ord[0] / image_width,
            'y': 100 * four_co_ord[1] / image_height,
            'width': 100 * four_co_ord[2] / image_width,
            'height': 100 * four_co_ord[3] / image_height,
            #'rotation': 0
        }
        ocr_box.append({"bbox":target_bbox,"text_result":text})
    
    transform_data["image"] = data_dict["image"]
    transform_data["image_width"] = data_dict["image_width"]
    transform_data["image_height"] = data_dict["image_height"]
    transform_data["ocrdata"] = ocr_box
    bill_ocr_data.append(transform_data)

# %%
pprint.pprint(bill_ocr_data[0]['ocrdata'])
#pprint.pprint(bill_ocr_data[1])
# Out:
# [{'bbox': {'height': 1.4819036762610431,
#            'width': 10.181818181818182,
#            'x': 37.97979797979798,
#            'y': 1.2539184952978057},
#   'text_result': ' BILL OF SUPPLY'},
#  {'bbox': {'height': 2.19435736677116,
#            'width': 7.757575757575758,
#            'x': 3.717171717171717,
#            'y': 1.6528925619834711},
#   'text_result': 'adani'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 8.767676767676768,
#            'x': 88.84848484848484,
#            'y': 1.6528925619834711},
#   'text_result': 'Scan QR code for'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 6.545454545454546,
#            'x': 66.94949494949495,
#            'y': 2.19435736677116},
#   'text_result': 'Electric '},
#  {'bbox': {'height': 1.139925904816187,
#            'width': 6.545454545454546,
#            'x': 72.92929292929293,
#            'y': 2.19435736677116},
#   'text_result': '429510'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 4.646464646464646,
#            'x': 67.39393939393939,
#            'y': 3.134796238244514},
#   'text_result': 'Smiles'},
#  {'bbox': {'height': 1.1684240524365916,
#            'width': 7.393939393939394,
#            'x': 88.72727272727273,
#            'y': 3.0208036477628952},
#   'text_result': ' kiosk payment'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 8.323232323232324,
#            'x': 39.15151515151515,
#            'y': 3.4482758620689653},
#   'text_result': 'COMMERCIAL'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 7.151515151515151,
#            'x': 72.76767676767676,
#            'y': 3.4482758620689653},
#   'text_result': 'Points Earned'},
#  {'bbox': {'height': 1.139925904816187,
#            'width': 6.707070707070707,
#            'x': 4.161616161616162,
#            'y': 4.274722143060701},
#   'text_result': 'Electricity'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 4.767676767676767,
#            'x': 54.02020202020202,
#            'y': 4.38871473354232},
#   'text_result': 'Joi n u at orow.'},
#  {'bbox': {'height': 0.7409518381305216,
#            'width': 7.313131313131313,
#            'x': 13.97979797979798,
#            'y': 4.673696209746367},
#   'text_result': 'The power of service'},
#  {'bbox': {'height': 0.7409518381305216,
#            'width': 2.8282828282828283,
#            'x': 60.72727272727273,
#            'y': 4.474209176403534},
#   'text_result': 'ngraha.org'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 27.393939393939394,
#            'x': 4.444444444444445,
#            'y': 7.409518381305215},
#   'text_result': 'KINGSTONE PROPERTY SERVICE LIMITED'},
#  {'bbox': {'height': 1.139925904816187,
#            'width': 5.656565656565657,
#            'x': 36.44444444444444,
#            'y': 7.409518381305215},
#   'text_result': ' BILL DATE'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 8.202020202020202,
#            'x': 54.303030303030305,
#            'y': 7.295525790823596},
#   'text_result': ' METER STATUS'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 8.484848484848484,
#            'x': 67.11111111111111,
#            'y': 7.409518381305215},
#   'text_result': 'CYCLE NUMBER'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 8.646464646464647,
#            'x': 81.25252525252525,
#            'y': 7.409518381305215},
#   'text_result': 'TYPE OF SUPPLY'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 25.454545454545453,
#            'x': 4.444444444444445,
#            'y': 8.634938728982616},
#   'text_result': 'COMMERZ OBEROI REALTY LIMITED OBEROI'},
#  {'bbox': {'height': 1.1684240524365916,
#            'width': 6.98989898989899,
#            'x': 36.44444444444444,
#            'y': 8.634938728982616},
#   'text_result': '01-12-2023'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 4.3232323232323235,
#            'x': 54.303030303030305,
#            'y': 8.748931319464235},
#   'text_result': 'Active'},
#  {'bbox': {'height': 0.9404388714733543,
#            'width': 1.7777777777777777,
#            'x': 67.11111111111111,
#            'y': 8.748931319464235},
#   'text_result': '31'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 29.454545454545453,
#            'x': 4.3232323232323235,
#            'y': 9.57537760045597},
#   'text_result': 'INTERNATIONAL BUSINESS PARK OBEROI GARDEN'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 23.636363636363637,
#            'x': 4.3232323232323235,
#            'y': 10.515816471929325},
#   'text_result': 'CITY GOREGAON EAST MUMBAI 400063'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 4.040404040404041,
#            'x': 36.44444444444444,
#            'y': 10.629809062410944},
#   'text_result': 'TARIFF'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 9.97979797979798,
#            'x': 54.464646464646464,
#            'y': 10.629809062410944},
#   'text_result': 'CONNECTION DATE'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 21.414141414141415,
#            'x': 67.11111111111111,
#            'y': 10.629809062410944},
#   'text_result': 'CONTRACT DEMAND (kVA) BILL NUMBER'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 4.161616161616162,
#            'x': 4.3232323232323235,
#            'y': 11.76973496722713},
#   'text_result': 'Mobile'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 7.2727272727272725,
#            'x': 11.030303030303031,
#            'y': 11.655742376745511},
#   'text_result': '70********19'},
#  {'bbox': {'height': 0.8264462809917356,
#            'width': 3.1515151515151514,
#            'x': 36.44444444444444,
#            'y': 11.883727557708749},
#   'text_result': 'HT II'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 6.8686868686868685,
#            'x': 54.303030303030305,
#            'y': 11.76973496722713},
#   'text_result': '01-11-2021'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 4.767676767676767,
#            'x': 67.27272727272727,
#            'y': 11.76973496722713},
#   'text_result': '956.00'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 9.212121212121213,
#            'x': 81.25252525252525,
#            'y': 11.76973496722713},
#   'text_result': '100013531423'},
#  {'bbox': {'height': 1.139925904816187,
#            'width': 3.4343434343434343,
#            'x': 4.3232323232323235,
#            'y': 13.023653462524935},
#   'text_result': 'Email'},
#  {'bbox': {'height': 0.7409518381305216,
#            'width': 11.595959595959595,
#            'x': 36.76767676767677,
#            'y': 14.049586776859504},
#   'text_result': 'BILL DISTRIBUTION NO.'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 8.484848484848484,
#            'x': 54.303030303030305,
#            'y': 13.85009974351667},
#   'text_result': ' BILLING STATUS'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 12.808080808080808,
#            'x': 67.11111111111111,
#            'y': 13.96409233399829},
#   'text_result': ' PRESENT READING DATE'},
#  {'bbox': {'height': 0.7409518381305216,
#            'width': 12.767676767676768,
#            'x': 81.41414141414141,
#            'y': 14.049586776859504},
#   'text_result': 'PREVIOUS READING DATE'},
#  {'bbox': {'height': 1.1684240524365916,
#            'width': 3.111111111111111,
#            'x': 4.161616161616162,
#            'y': 14.363066400683955},
#   'text_result': 'PAN'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 6.828282828282828,
#            'x': 11.030303030303031,
#            'y': 14.363066400683955},
#   'text_result': 'AA*****16P'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 14.909090909090908,
#            'x': 36.44444444444444,
#            'y': 14.904531205471644},
#   'text_result': ' Malad/Dindoshi/31/M03/'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 4.929292929292929,
#            'x': 54.303030303030305,
#            'y': 14.990025648332859},
#   'text_result': ' Regular'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 6.98989898989899,
#            'x': 67.11111111111111,
#            'y': 14.990025648332859},
#   'text_result': '30-11-2023'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 6.98989898989899,
#            'x': 81.0909090909091,
#            'y': 14.990025648332859},
#   'text_result': '31-10-2023'},
#  {'bbox': {'height': 1.139925904816187,
#            'width': 2.8282828282828283,
#            'x': 4.161616161616162,
#            'y': 15.61698489598176},
#   'text_result': 'GST'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 15.151515151515152,
#            'x': 15.636363636363637,
#            'y': 20.718153320034197},
#   'text_result': 'CA NO:153144669'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 6.101010101010101,
#            'x': 34.38383838383838,
#            'y': 20.632658877172982},
#   'text_result': 'Bill Month'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 9.656565656565656,
#            'x': 54.18181818181818,
#            'y': 20.632658877172982},
#   'text_result': 'Units Consumed'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 10.868686868686869,
#            'x': 67.55555555555556,
#            'y': 20.632658877172982},
#   'text_result': 'Current Month Bill'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 12.525252525252526,
#            'x': 81.53535353535354,
#            'y': 20.632658877172982},
#   'text_result': 'Previous Outstanding'},
#  {'bbox': {'height': 1.139925904816187,
#            'width': 5.9393939393939394,
#            'x': 34.38383838383838,
#            'y': 22.086064405813623},
#   'text_result': 'NOV-23'},
#  {'bbox': {'height': 1.139925904816187,
#            'width': 6.262626262626263,
#            'x': 54.303030303030305,
#            'y': 22.086064405813623},
#   'text_result': '148260'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 10.1010101010101,
#            'x': 67.71717171717172,
#            'y': 22.200056996295242},
#   'text_result': '1759534.69'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 7.757575757575758,
#            'x': 81.53535353535354,
#            'y': 22.200056996295242},
#   'text_result': '17201.57'},
#  {'bbox': {'height': 1.3679110857794243,
#            'width': 14.707070707070708,
#            'x': 15.636363636363637,
#            'y': 22.79851809632374},
#   'text_result': '1776840.00*'},
#  {'bbox': {'height': 0.7124536905101169,
#            'width': 14.464646464646465,
#            'x': 34.505050505050505,
#            'y': 23.65346252493588},
#   'text_result': 'Bill Period: 01-11-2023 - 30.11.2023'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 10.383838383838384,
#            'x': 54.18181818181818,
#            'y': 23.53946993445426},
#   'text_result': ' Previous Units : 159900'},
#  {'bbox': {'height': 1.3679110857794243,
#            'width': 12.808080808080808,
#            'x': 16.2020202020202,
#            'y': 25.93331433456825},
#   'text_result': 'Due Date: 16-12-2023'},
#  {'bbox': {'height': 0.7124536905101169,
#            'width': 44.2020202020202,
#            'x': 34.82828282828283,
#            'y': 26.987745796523225},
#   'text_result': ': Round sum paybale by discount date 08-12-2023: Amt '
#                  '<1762710.00 Discount 14130.19'},
#  {'bbox': {'height': 0.7124536905101169,
#            'width': 12.363636363636363,
#            'x': 15.313131313131313,
#            'y': 28.127671701339413},
#   'text_result': 'o only current bill amount'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 42.38383838383838,
#            'x': 34.82828282828283,
#            'y': 28.327158734682246},
#   'text_result': ': Round sum paybale after due date 16-12-2023 : Amt '
#                  '<1798830.00# DPC <21994.18'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 19.757575757575758,
#            'x': 4.929292929292929,
#            'y': 28.640638358506695},
#   'text_result': 'previous balance is payable immediately'},
#  {'bbox': {'height': 0.7124536905101169,
#            'width': 19.95959595959596,
#            'x': 34.06060606060606,
#            'y': 31.575947563408377},
#   'text_result': 'Nearest Collection Centre (Cash/Cheque)'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 22.90909090909091,
#            'x': 5.494949494949495,
#            'y': 31.860929039612426},
#   'text_result': 'Scan code to pay your bill via (use any UPI app)'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 9.212121212121213,
#            'x': 87.07070707070707,
#            'y': 31.77543459675121},
#   'text_result': 'Suhas Parab'},
#  {'bbox': {'height': 1.1684240524365916,
#            'width': 42.101010101010104,
#            'x': 33.77777777777778,
#            'y': 32.48788828726133},
#   'text_result': 'Adani Electricity, Malad, MBH colony, Dindoshi, Western '
#                  'Express Highway.'},
#  {'bbox': {'height': 1.139925904816187,
#            'width': 4.888888888888889,
#            'x': 5.212121212121212,
#            'y': 33.22884012539185},
#   'text_result': 'LPIT'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 7.2727272727272725,
#            'x': 11.757575757575758,
#            'y': 33.22884012539185},
#   'text_result': 'BBPS'},
#  {'bbox': {'height': 1.1684240524365916,
#            'width': 6.262626262626263,
#            'x': 22.464646464646464,
#            'y': 33.11484753491023},
#   'text_result': 'NACH'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 9.05050505050505,
#            'x': 87.07070707070707,
#            'y': 33.029353092049014},
#   'text_result': 'Head-HT Metering'},
#  {'bbox': {'height': 1.139925904816187,
#            'width': 17.414141414141415,
#            'x': 33.77777777777778,
#            'y': 33.34283271587347},
#   'text_result': 'Malad(East)., Mumbai-400097'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 13.373737373737374,
#            'x': 4.3232323232323235,
#            'y': 36.05015673981191},
#   'text_result': 'CONSUMPTION TREND'},
#  {'bbox': {'height': 1.139925904816187,
#            'width': 9.414141414141413,
#            'x': 24.525252525252526,
#            'y': 35.936164149330295},
#   'text_result': 'Current year'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 9.656565656565656,
#            'x': 37.05050505050505,
#            'y': 36.05015673981191},
#   'text_result': 'V Previous year'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 26.78787878787879,
#            'x': 59.23232323232323,
#            'y': 36.05015673981191},
#   'text_result': 'MAJOR BILL COMPONENTS (Rounded off amt)'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 10.424242424242424,
#            'x': 61.17171717171717,
#            'y': 40.63835850669707},
#   'text_result': 'RAC/GRPHOU /: 0'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 4.040404040404041,
#            'x': 5.494949494949495,
#            'y': 41.15132516386435},
#   'text_result': '178800'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 5.05050505050505,
#            'x': 63.55555555555556,
#            'y': 41.778284411513255},
#   'text_result': 'PEN/INC'},
#  {'bbox': {'height': 0.8264462809917356,
#            'width': 3.272727272727273,
#            'x': 68.16161616161617,
#            'y': 41.97777144485608},
#   'text_result': '10'},
#  {'bbox': {'height': 0.8264462809917356,
#            'width': 2.2626262626262625,
#            'x': 66.06060606060606,
#            'y': 43.03220290681106},
#   'text_result': 'FAC'},
#  {'bbox': {'height': 1.139925904816187,
#            'width': 4.0,
#            'x': 5.656565656565657,
#            'y': 43.34568253063551},
#   'text_result': '134100'},
#  {'bbox': {'height': 0.7409518381305216,
#            'width': 2.6666666666666665,
#            'x': 68.76767676767676,
#            'y': 43.11769734967227},
#   'text_result': '1 0'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 4.767676767676767,
#            'x': 63.55555555555556,
#            'y': 44.058136221145624},
#   'text_result': 'NET OTH'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 4.0,
#            'x': 68.60606060606061,
#            'y': 44.058136221145624},
#   'text_result': '1 107'},
#  {'bbox': {'height': 1.139925904816187,
#            'width': 5.575757575757576,
#            'x': 62.62626262626262,
#            'y': 44.970076944998574},
#   'text_result': 'NET PREV'},
#  {'bbox': {'height': 1.1684240524365916,
#            'width': 3.717171717171717,
#            'x': 5.818181818181818,
#            'y': 45.51154174978626},
#   'text_result': '89400'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 4.444444444444445,
#            'x': 69.57575757575758,
#            'y': 45.0840695354802},
#   'text_result': '17,201'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 5.818181818181818,
#            'x': 62.343434343434346,
#            'y': 46.25249358791679},
#   'text_result': 'WHEELING'},
#  {'bbox': {'height': 0.7409518381305216,
#            'width': 4.0,
#            'x': 73.21212121212122,
#            'y': 46.451980621259615},
#   'text_result': '1,43,812'},
#  {'bbox': {'height': 1.139925904816187,
#            'width': 4.484848484848484,
#            'x': 63.676767676767675,
#            'y': 47.39241949273297},
#   'text_result': 'FIX/DEM'},
#  {'bbox': {'height': 1.139925904816187,
#            'width': 5.1313131313131315,
#            'x': 75.11111111111111,
#            'y': 47.16443431176973},
#   'text_result': '2,54,250'},
#  {'bbox': {'height': 1.139925904816187,
#            'width': 3.595959595959596,
#            'x': 5.9393939393939394,
#            'y': 47.81989170703904},
#   'text_result': '44700'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 7.595959595959596,
#            'x': 60.56565656565657,
#            'y': 48.53234539754916},
#   'text_result': 'DUTIES/TAXES'},
#  {'bbox': {'height': 1.1684240524365916,
#            'width': 4.606060606060606,
#            'x': 77.0909090909091,
#            'y': 48.53234539754916},
#   'text_result': '3,46,515'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 8.767676767676768,
#            'x': 59.23232323232323,
#            'y': 49.70076944998575},
#   'text_result': 'ENERGY(Inc TOD)'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 5.212121212121212,
#            'x': 90.18181818181819,
#            'y': 49.70076944998575},
#   'text_result': '10,14,957'},
#  {'bbox': {'height': 0.7409518381305216,
#            'width': 2.2222222222222223,
#            'x': 52.24242424242424,
#            'y': 51.04018238814477},
#   'text_result': 'DEC'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 19.636363636363637,
#            'x': 70.98989898989899,
#            'y': 52.18010829296096},
#   'text_result': '2537405074807612201014960'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 49.41414141414141,
#            'x': 4.0,
#            'y': 56.34083784554004},
#   'text_result': 'PRINCIPAL PLACE OF BUSINESS /CONSUMER GRIEVANCE REDRESSAL '
#                  'FORUM (CGRF)'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 8.484848484848484,
#            'x': 59.07070707070707,
#            'y': 56.255343402678825},
#   'text_result': 'HELP CENTER'},
#  {'bbox': {'height': 1.139925904816187,
#            'width': 46.707070707070706,
#            'x': 4.040404040404041,
#            'y': 58.33570817896837},
#   'text_result': ' Address: Adani Electricity, Devidas Lane, Off SvP Road, '
#                  'Near Devidas Lane Telephone Exchange'},
#  {'bbox': {'height': 0.7124536905101169,
#            'width': 15.151515151515152,
#            'x': 4.3232323232323235,
#            'y': 59.27614705044172},
#   'text_result': 'Borivali West, Mumbai 400 103'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 13.212121212121213,
#            'x': 62.22222222222222,
#            'y': 59.475634083784556},
#   'text_result': '19122 Toll Free No.(24X7)'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 15.636363636363637,
#            'x': 75.87878787878788,
#            'y': 59.58962667426617},
#   'text_result': 'www.adanielectricity.com'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 26.060606060606062,
#            'x': 4.161616161616162,
#            'y': 60.72955257908236},
#   'text_result': 'Email: consumerforum.mumbaielectricity@adani.com'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 17.13131313131313,
#            'x': 32.72727272727273,
#            'y': 60.72955257908236},
#   'text_result': 'Website: cgrf.adanielectricity.com'},
#  {'bbox': {'height': 0.7124536905101169,
#            'width': 19.19191919191919,
#            'x': 62.343434343434346,
#            'y': 61.47050441721288},
#   'text_result': 'helpdesk.mumbaielectricity@adani.com'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 11.474747474747474,
#            'x': 4.161616161616162,
#            'y': 62.097463664861785},
#   'text_result': 'Phone: 022-50745004'},
#  {'bbox': {'height': 1.1684240524365916,
#            'width': 32.121212121212125,
#            'x': 61.333333333333336,
#            'y': 63.009404388714735},
#   'text_result': 'Adani Electricity, Malad, MBH colony, Dindoshi, Western '
#                  'Express'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 19.19191919191919,
#            'x': 62.505050505050505,
#            'y': 63.750356226845255},
#   'text_result': 'Highway, Malad(East), Mumbai-400097'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 15.636363636363637,
#            'x': 4.0,
#            'y': 65.63123396979196},
#   'text_result': 'REGISTERED OFFICE AEML'},
#  {'bbox': {'height': 0.7409518381305216,
#            'width': 26.22222222222222,
#            'x': 60.4040404040404,
#            'y': 66.03020803647763},
#   'text_result': 'For power interruption complaint or restoration status'},
#  {'bbox': {'height': 1.3679110857794243,
#            'width': 32.72727272727273,
#            'x': 59.83838383838384,
#            'y': 66.77115987460814},
#   'text_result': 'SMS POwER<9 digit account no.> to 7065313030 from mobile '
#                  'no.'},
#  {'bbox': {'height': 0.7124536905101169,
#            'width': 15.030303030303031,
#            'x': 4.767676767676767,
#            'y': 68.13907096038757},
#   'text_result': 'Address: Adani Corporate Hous'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 30.828282828282827,
#            'x': 20.08080808080808,
#            'y': 68.02507836990596},
#   'text_result': 'e, Shantigram, Near Vaishno Devi Circle, S. G. Highway, '
#                  'Khodiyar.'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 35.43434343434343,
#            'x': 60.121212121212125,
#            'y': 67.91108577942434},
#   'text_result': 'Whatsapp P0wER <9 digit account no> to 9594519122 from any '
#                  'mobile'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 16.96969696969697,
#            'x': 4.606060606060606,
#            'y': 68.73753206041607},
#   'text_result': 'Ahmedabad, Gujarat, India-382421'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 34.38383838383838,
#            'x': 59.95959595959596,
#            'y': 69.99145055571388},
#   'text_result': 'Give us missed call on 1800 532 9998 from your registered '
#                  'mobile no.'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 16.242424242424242,
#            'x': 4.606060606060606,
#            'y': 70.7324023938444},
#   'text_result': 'CIN: U74999GJ2008PLC107256'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 9.93939393939394,
#            'x': 23.67676767676768,
#            'y': 70.7324023938444},
#   'text_result': 'PAN: AADCD0086F'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 13.97979797979798,
#            'x': 37.93939393939394,
#            'y': 70.7324023938444},
#   'text_result': 'GSTIN: 27AADCD0086F1ZW'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 18.90909090909091,
#            'x': 60.121212121212125,
#            'y': 71.15987460815047},
#   'text_result': 'Portal Related Complaint call us:19122'},
#  {'bbox': {'height': 0.7124536905101169,
#            'width': 30.626262626262626,
#            'x': 60.282828282828284,
#            'y': 72.6132801367911},
#   'text_result': 'For internal complaint redressal system(IcRs), visit our '
#                  'website:'},
#  {'bbox': {'height': 0.8264462809917356,
#            'width': 1.6565656565656566,
#            'x': 67.55555555555556,
#            'y': 74.69364491308065},
#   'text_result': 'f'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 7.878787878787879,
#            'x': 69.05050505050505,
#            'y': 74.57965232259903},
#   'text_result': 'Ono'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 5.373737373737374,
#            'x': 60.84848484848485,
#            'y': 74.89313194642348},
#   'text_result': 'Join us on:'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 13.373737373737374,
#            'x': 4.3232323232323235,
#            'y': 75.63408378455401},
#   'text_result': 'IMPORTANT MESSAGE'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 35.39393939393939,
#            'x': 3.878787878787879,
#            'y': 77.79994300370475},
#   'text_result': 'o Please pay this bill by Online / RTGS / NEFT / Cheque or '
#                  'Demand Draft.'},
#  {'bbox': {'height': 1.3679110857794243,
#            'width': 32.16161616161616,
#            'x': 61.73737373737374,
#            'y': 78.85437446565973},
#   'text_result': 'Special Summary Revision Programme 2024'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 51.474747474747474,
#            'x': 3.717171717171717,
#            'y': 80.30777999430038},
#   'text_result': 'o W.e.f 1st April 2022 TCS @ O.1% is applicable on '
#                  'collection amount exceeding Rs.50 Lakh. TCS at penal'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 39.878787878787875,
#            'x': 5.05050505050505,
#            'y': 81.13422627529211},
#   'text_result': 'rate is applicable for no PAN and u/s. 206cCA for non-filing '
#                  'of Income Tax Return'},
#  {'bbox': {'height': 1.139925904816187,
#            'width': 6.383838383838384,
#            'x': 81.4949494949495,
#            'y': 80.79224850384725},
#   'text_result': 'cember2023'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 50.14141414141414,
#            'x': 3.717171717171717,
#            'y': 82.81561698489598},
#   'text_result': 'O In view of MERC order in case no. 325 of 2019, cash '
#                  'payment limit towards electricity bills is fixed at'},
#  {'bbox': {'height': 1.3679110857794243,
#            'width': 28.0,
#            'x': 63.676767676767675,
#            'y': 83.32858364206326},
#   'text_result': 'For an energy-efficient democracy,'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 45.25252525252525,
#            'x': 4.767676767676767,
#            'y': 83.64206326588771},
#   'text_result': 'Rs.5,ooo/- per account per month. For payment of amount '
#                  'greater than Rs.5,ooo please use'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 25.575757575757574,
#            'x': 4.929292929292929,
#            'y': 84.38301510401824},
#   'text_result': 'convenient digital channels / online / cheque modes'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 17.575757575757574,
#            'x': 69.05050505050505,
#            'y': 84.58250213736108},
#   'text_result': "let's register as voters"},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 37.494949494949495,
#            'x': 3.717171717171717,
#            'y': 85.40894841835281},
#   'text_result': 'o Meter reading as on O1.01.24 will be downloaded for '
#                  'preparing DEC-23 bill'},
#  {'bbox': {'height': 1.3394129381590196,
#            'width': 15.919191919191919,
#            'x': 69.93939393939394,
#            'y': 85.63693359931604},
#   'text_result': 'and fulfill your duty.'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 19.636363636363637,
#            'x': 68.0,
#            'y': 86.97634653747507},
#   'text_result': 'Do check your name in the voter list.'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 24.282828282828284,
#            'x': 65.61616161616162,
#            'y': 87.8027928184668},
#   'text_result': "If it's not there, register yourself immediately."},
#  {'bbox': {'height': 0.7409518381305216,
#            'width': 5.656565656565657,
#            'x': 77.37373737373737,
#            'y': 90.62410943288687},
#   'text_result': 'egistratior'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 13.858585858585858,
#            'x': 70.66666666666667,
#            'y': 91.4505557138786},
#   'text_result': 'visit voters.eci.gov.in'},
#  {'bbox': {'height': 0.7124536905101169,
#            'width': 2.5454545454545454,
#            'x': 88.08080808080808,
#            'y': 93.75890567113137},
#   'text_result': 'DE'},
#  {'bbox': {'height': 1.139925904816187,
#            'width': 5.212121212121212,
#            'x': 62.06060606060606,
#            'y': 94.78483898546594},
#   'text_result': 'Google Play'},
#  {'bbox': {'height': 1.4534055286406384,
#            'width': 5.97979797979798,
#            'x': 88.08080808080808,
#            'y': 94.5853519521231},
#   'text_result': 'App Store'},
#  {'bbox': {'height': 1.0259333143345684,
#            'width': 11.757575757575758,
#            'x': 72.04040404040404,
#            'y': 95.01282416642918},
#   'text_result': 'Voter Helpline app.'},
#  {'bbox': {'height': 1.139925904816187,
#            'width': 4.040404040404041,
#            'x': 91.51515151515152,
#            'y': 97.80564263322884},
#   'text_result': 'E.&0.E'},
#  {'bbox': {'height': 1.0544314619549728,
#            'width': 25.77777777777778,
#            'x': 58.02020202020202,
#            'y': 98.11912225705329},
#   'text_result': 'Dt.31/12/2027). OW4819 Dated 29/11/2023, GRN NO.'},
#  {'bbox': {'height': 0.7409518381305216,
#            'width': 18.181818181818183,
#            'x': 4.606060606060606,
#            'y': 98.94556853804502},
#   'text_result': 'MH010146824202324E, DATE:27/10/'}]

# %% [markdown]
# ### Search keyword in Template
# #### Search only in first page (bill_ocr_data[0])

# %%
def search_all_keys(target_data, substrings):
    result = all(
        any(
            re.search(re.compile(re.escape(keyword)), item['text_result'])
            for item in target_data
        )
        for keyword in substrings
    )
    #result = all(any(keyword in item['text_result'] for item in target_data) for keyword in substrings)
    return result

found_template = {}

for configitem in configdata:
    #for entry in configitem['keywords']:
    substrings = [entry['key'] for entry in configitem['keywords']]
    #print(substrings)
    if search_all_keys(bill_ocr_data[0]['ocrdata'], substrings):
        found_template = configitem.copy()
print(found_template)
# Out:
# {'name': 'Adani Commercial HT II', 'keywords': [{'key': 'adani', 'required': True, 'box': {'x': 3.715670436187399, 'y': 1.6524216524216524, 'width': 7.754442649434572, 'height': 2.2222222222222223}}, {'key': 'COMMERCIAL', 'required': True, 'box': {'x': 39.17609046849758, 'y': 3.4188034188034186, 'width': 8.319870759289175, 'height': 1.0826210826210827}}, {'key': 'HT II', 'required': True, 'box': {'x': 36.42972536348948, 'y': 11.794871794871773, 'width': 5.217422472544567, 'height': 1.1396011396011383}}], 'pages': ['Adani_Commercial_HT_II_page_1.json', 'Adani_Commercial_HT_II_page_2.json']}

# %%
def calculate_iou(bbox1, bbox2):
  """
  Calculates the Intersection over Union (IoU) between two bounding boxes.

  Args:
      bbox1: A dictionary representing the first bounding box with keys 'x', 'y', 'width', and 'height'.
      bbox2: A dictionary representing the second bounding box with the same keys.

  Returns:
      The IoU value between the two bounding boxes (float).
  """
  # Calculate bottom right coordinates for each bbox
  bbox1_br_x = bbox1['x'] + bbox1['width']
  bbox1_br_y = bbox1['y'] + bbox1['height']
  bbox2_br_x = bbox2['x'] + bbox2['width']
  bbox2_br_y = bbox2['y'] + bbox2['height']

  # Determine intersection coordinates
  xmin = max(bbox1['x'], bbox2['x'])
  ymin = max(bbox1['y'], bbox2['y'])
  xmax = min(bbox1_br_x, bbox2_br_x)
  ymax = min(bbox1_br_y, bbox2_br_y)

  # Calculate intersection area (handle no overlap case)
  intersection_area = 0
  if xmax >= xmin and ymax >= ymin:
    intersection_area = (xmax - xmin) * (ymax - ymin)

  # Calculate union area
  union_area = (bbox1['width'] * bbox1['height']) + (bbox2['width'] * bbox2['height']) - intersection_area

  # Calculate and return IoU
  iou = intersection_area / union_area if union_area > 0 else 0
  return iou

# %% [markdown]
# #### New Comparision Logic with Required and Optional Keywords

# %%
def find_matching_template(templates, target_data):
    for template in templates:
        print("Searching Template:",template["name"])
        found_required = 0
        matched_optional_keywords = []
        found_optional = False
        iou_match = True
        for template_keyword in template['keywords']:
            if template_keyword["required"]:
                found = False
                for keyword in target_data:
                    #text = keyword["text_result"].lower().strip()
                    text = keyword["text_result"].strip()
                    #print(f'\t{text} == {template_keyword["key"].lower()}')
                    #if text == template_keyword["key"].lower():
                    if template_keyword["key"] in text:
                        print(template_keyword["box"])
                        print(keyword["bbox"])
                        iou = calculate_iou(template_keyword["box"],keyword["bbox"])
                        if iou < 0.3:
                            iou_match = False
                        print("iou:",iou)
                        found_required += 1  
                        #print(f'\t\t{found_required}')
                        found = True
                        break
                if not found:
                    break # Exit inner loop if a required keyword is missing in this template
            else: # Optional keyword
                #found_optional = found_optional or any(keyword["text_result"].lower().strip() == tk["key"].lower() for tk in template["keywords"])
                matching_items = [(template_keyword, keyword) for keyword in target_data if template_keyword["key"] in keyword["text_result"]]
                if matching_items:
                    for keyword_match, item_match in matching_items:
                        #print(f"Found match: '{keyword_match['key']}' in '{item_match['text_result']}'")
                        print(keyword_match["box"])
                        print(item_match["bbox"])
                        o_iou = calculate_iou(keyword_match["box"],item_match["bbox"])
                        if o_iou < 0.3:
                            iou_match = False
                        print("oiu: ",o_iou)
                        matched_optional_keywords.append(template_keyword["key"])
                    found_optional = True
                '''
                if any(template_keyword["key"] in keyword["text_result"] for keyword in target_data):
                    matched_optional_keywords.append(template_keyword["key"])
                    found_optional = True
                '''    
        if found_required == len(template["keywords"]) - len([kw for kw in template["keywords"] if not kw["required"]]):
            # All required keywords and at least one optional keyword found
            return template,matched_optional_keywords,iou_match
    return None

matched_template,matched_optional_keywords,iou_match  = find_matching_template(configdata, bill_ocr_data[0]['ocrdata'])

if matched_template:
  print(f"Matching template: {matched_template['name']}")
  if matched_optional_keywords:
    print(f"Matched optional keywords: {matched_optional_keywords}")
  else:
    print("No optional keywords matched")
  print("IOU MATCH: ",iou_match)
else:
  print("No matching template found")

#pprint.pprint(matched_template)
# Out:
# Searching Template: Adani Commercial HT II
# {'x': 3.715670436187399, 'y': 1.6524216524216524, 'width': 7.754442649434572, 'height': 2.2222222222222223}
# {'x': 3.717171717171717, 'y': 1.6528925619834711, 'width': 7.757575757575758, 'height': 2.19435736677116}
# iou: 0.9866873472836515
# {'x': 39.17609046849758, 'y': 3.4188034188034186, 'width': 8.319870759289175, 'height': 1.0826210826210827}
# {'x': 39.15151515151515, 'y': 3.4482758620689653, 'width': 8.323232323232324, 'height': 1.0259333143345684}
# iou: 0.9425837166579175
# {'x': 36.42972536348948, 'y': 11.794871794871773, 'width': 5.217422472544567, 'height': 1.1396011396011383}
# {'x': 36.44444444444444, 'y': 11.883727557708749, 'width': 3.1515151515151514, 'height': 0.8264462809917356}
# iou: 0.438051477788025
# Matching template: Adani Commercial HT II
# No optional keywords matched
# IOU MATCH:  True

# %% [markdown]
# ### Match position of keywords. If all matched then finalise Template

# %%
for keys in matched_template["keywords"]:
    target_bbox_dict = result_dict = next((item for item in bill_ocr_data[0]['ocrdata'] if item['text_result'] == keys['key']), None)
    print(keys['box'], target_bbox_dict['bbox'])

# %% [markdown]
# #### Load Template Json file having master data for matching fields
# Example : Adani_Commercial_HT_II_page_1.json, Adani_Commercial_HT_II_page_2.json

# %%
def extract_data(master_data,bill_data):
    annotations = master_data.get("annotations", {})
    for variable_name, master_variable_data in annotations.items():
        for bill_data_item in bill_data:
            target_bbox = bill_data_item["bbox"].copy()
            try:
                if isinstance(master_variable_data['box'], dict):
                    iou = calculate_iou(master_variable_data['box'],target_bbox) 
                    if(iou >= 0.3):
                        print(f"Found: {variable_name}: {bill_data_item['text_result']} == {iou}")
                    elif(0.1 <= iou < 0.3):
                        print("No match found",iou)
                else:
                    print("Not dict box:", master_variable_data)
            except TypeError:
                print("No box found: ",master_variable_data)

# %%
template_folder = f"{work_dir}/template_data/master_templates"

for i,json_template in enumerate(found_template['pages']):
    json_file_path = f"{template_folder}/{json_template}"
    master_data = {}
    with open(json_file_path, 'r') as file:
        master_data = json.load(file)
        ### ---- Compare Bill OCR Data (bill_ocr_data[0]['ocrdata']) with Master Veairble Data (data)
        print(f"Extracting using {json_template}")
        #print(bill_ocr_data[i]['ocrdata'])
        extract_data(master_data,bill_ocr_data[i]['ocrdata'])
